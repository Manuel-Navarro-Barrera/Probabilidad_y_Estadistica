# %% [markdown]
# <a href="https://colab.research.google.com/github/Manuel-Navarro-Barrera/Probabilidad_y_Estadistica/blob/main/Unidad%201/Practica_4_Tablas_de_Frecuencias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# basado en el LIBRO para Administracion
# creamos una lista vacia que representa la edad de las personas
import random
edades = []
# hacemos un ciclo para generar 100 numeros aleatorios que representan la edad de las personas
for i in range (100):
  # generamos un numero aleatorio con la funcion randint y lo guardamos en la variable
  numero_aleatorio = random.randint(18,78)
  # Agregamos el numero aleatorio a la lista de Valores
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [54, 21, 43, 23, 20, 74, 25, 40, 46, 24, 31, 40, 24, 26, 26, 48, 37, 56, 60, 52, 76, 60, 57, 42, 32, 27, 22, 26, 42, 47, 33, 42, 46, 23, 64, 47, 77, 49, 47, 27, 51, 64, 72, 77, 26, 71, 56, 27, 29, 18, 40, 52, 68, 54, 68, 65, 67, 44, 47, 20, 69, 54, 49, 62, 63, 66, 34, 71, 38, 47, 70, 37, 66, 19, 64, 23, 50, 70, 67, 55, 38, 70, 23, 46, 37, 70, 75, 39, 33, 31, 57, 29, 27, 71, 62, 76, 39, 50, 62, 62]

# %%
import pandas as pd

# %%
# Crear un Dataframe de pandas con los numeros aleatorios
df = pd.DataFrame(edades, columns=['Edades'])
df.head()
# Out:
#    Edades
# 0      54
# 1      21
# 2      43
# 3      23
# 4      20
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Edades'].plot(kind='hist', bins=20, title='Edades')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['Edades'].plot(kind='line', figsize=(8, 4), title='Edades')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# Calcular la tabla de distribucion de frecuencias
tabla_frecuencias = df['Edades'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de Distribucion de frecuencias
print("Tabla de Distribucion de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribucion de Frecuencias:
#     Edad  Frecuencia
# 47    18           1
# 35    19           1
# 24    20           2
# 36    21           1
# 48    22           1
# 2     23           4
# 25    24           2
# 31    25           1
# 4     26           4
# 1     27           4
# 14    29           2
# 22    31           2
# 44    32           1
# 21    33           2
# 38    34           1
# 9     37           3
# 18    38           2
# 27    39           2
# 12    40           3
# 6     42           3
# 34    43           1
# 43    44           1
# 11    46           3
# 0     47           5
# 46    48           1
# 16    49           2
# 19    50           2
# 39    51           1
# 29    52           2
# 10    54           3
# 33    55           1
# 26    56           2
# 28    57           2
# 23    60           2
# 5     62           4
# 40    63           1
# 7     64           3
# 45    65           1
# 15    66           2
# 20    67           2
# 13    68           2
# 42    69           1
# 3     70           4
# 8     71           3
# 41    72           1
# 37    74           1
# 32    75           1
# 30    76           2
# 17    77           2
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# tabla_frecuencias['Edad'].plot(kind='hist', bins=20, title='Edad')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# tabla_frecuencias['Frecuencia'].plot(kind='hist', bins=20, title='Frecuencia')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# tabla_frecuencias.plot(kind='scatter', x='Edad', y='Frecuencia', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Edad']
#   ys = series['Frecuencia']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = tabla_frecuencias.sort_values('Edad', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Edad')
# _ = plt.ylabel('Frecuencia')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Edad']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Edad'}, axis=1)
#               .sort_values('Edad', ascending=True))
#   xs = counted['Edad']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = tabla_frecuencias.sort_values('Edad', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Edad')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# tabla_frecuencias['Edad'].plot(kind='line', figsize=(8, 4), title='Edad')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# tabla_frecuencias['Frecuencia'].plot(kind='line', figsize=(8, 4), title='Frecuencia')
# plt.gca().spines[['top', 'right']].set_visible(False)
