# %% [markdown]
# <a href="https://colab.research.google.com/github/Manuel-Navarro-Barrera/Probabilidad_y_Estadistica/blob/main/Unidad%201/Practica_4_Tablas_de_Frecuencias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practica 4
# ### Materia: Probabilidad y Estadistica
# ## Profesor: Rodriguez Rivas Jose Gabriel
# #### Alumno: Manuel Alejandro Navarro Barrera

# %%
# basado en el LIBRO para Administracion
# creamos una lista vacia que representa la edad de las personas
import random
edades = []
# hacemos un ciclo para generar 100 numeros aleatorios que representan la edad de las personas
for i in range (100):
  # generamos un numero aleatorio con la funcion randint y lo guardamos en la variable
  numero_aleatorio = random.randint(18,78)
  # Agregamos el numero aleatorio a la lista de Valores
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [37, 20, 28, 51, 73, 24, 45, 41, 70, 29, 36, 28, 74, 61, 60, 51, 71, 23, 71, 56, 23, 71, 52, 41, 30, 28, 25, 64, 49, 70, 67, 63, 47, 47, 24, 74, 41, 69, 68, 32, 77, 34, 47, 58, 57, 20, 69, 47, 26, 41, 70, 24, 72, 75, 19, 47, 64, 20, 35, 22, 28, 64, 45, 27, 76, 75, 39, 64, 51, 60, 64, 46, 35, 39, 49, 33, 25, 24, 77, 76, 74, 18, 18, 70, 18, 48, 52, 35, 69, 46, 49, 22, 60, 18, 28, 27, 33, 53, 43, 19]

# %%
import pandas as pd

# %%
# Crear un Dataframe de pandas con los numeros aleatorios
df = pd.DataFrame(edades, columns=['Edades'])
df.head()
# Out:
#    Edades
# 0      37
# 1      20
# 2      28
# 3      51
# 4      73

# %%
# Calcular la tabla de distribucion de frecuencias
tabla_frecuencias = df['Edades'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de Distribucion de frecuencias
print("Tabla de Distribucion de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribucion de Frecuencias:
#     Edad  Frecuencia
# 5     18           4
# 15    19           2
# 14    20           3
# 17    22           2
# 25    23           2
# 6     24           4
# 22    25           2
# 33    26           1
# 18    27           2
# 1     28           5
# 44    29           1
# 40    30           1
# 37    32           1
# 26    33           2
# 36    34           1
# 7     35           3
# 43    36           1
# 31    37           1
# 23    39           2
# 3     41           4
# 46    43           1
# 27    45           2
# 20    46           2
# 2     47           5
# 29    48           1
# 8     49           3
# 13    51           3
# 24    52           2
# 30    53           1
# 41    56           1
# 34    57           1
# 35    58           1
# 10    60           3
# 42    61           1
# 32    63           1
# 0     64           5
# 39    67           1
# 38    68           1
# 12    69           3
# 4     70           4
# 11    71           3
# 28    72           1
# 45    73           1
# 9     74           3
# 21    75           2
# 19    76           2
# 16    77           2

# %%
tabla_frecuencias['Frec Rel'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Rel
# 5     18           4      0.04
# 15    19           2      0.02
# 14    20           3      0.03
# 17    22           2      0.02
# 25    23           2      0.02
# 6     24           4      0.04
# 22    25           2      0.02
# 33    26           1      0.01
# 18    27           2      0.02
# 1     28           5      0.05
# 44    29           1      0.01
# 40    30           1      0.01
# 37    32           1      0.01
# 26    33           2      0.02
# 36    34           1      0.01
# 7     35           3      0.03
# 43    36           1      0.01
# 31    37           1      0.01
# 23    39           2      0.02
# 3     41           4      0.04
# 46    43           1      0.01
# 27    45           2      0.02
# 20    46           2      0.02
# 2     47           5      0.05
# 29    48           1      0.01
# 8     49           3      0.03
# 13    51           3      0.03
# 24    52           2      0.02
# 30    53           1      0.01
# 41    56           1      0.01
# 34    57           1      0.01
# 35    58           1      0.01
# 10    60           3      0.03
# 42    61           1      0.01
# 32    63           1      0.01
# 0     64           5      0.05
# 39    67           1      0.01
# 38    68           1      0.01
# 12    69           3      0.03
# 4     70           4      0.04
# 11    71           3      0.03
# 28    72           1      0.01
# 45    73           1      0.01
# 9     74           3      0.03
# 21    75           2      0.02
# 19    76           2      0.02
# 16    77           2      0.02

# %%
tabla_frecuencias['Frec Porc'] = tabla_frecuencias['Frecuencia Relativa'] / n * 100
tabla_frecuencias
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Frecuencia Relativa'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-6e33296ee652> in <cell line: 0>()
# ----> 1 tabla_frecuencias['Frec Porc'] = tabla_frecuencias['Frecuencia Relativa'] / n * 100
#       2 tabla_frecuencias
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Frecuencia Relativa'

# %%
tabla_frecuencias['Frec Ac'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias

# %% [markdown]
# # Regla de Sturges
#
# c = 1 + log2(N)

# %%
# Importamos la libreria math de funciones matematicas
import math

# %%
print (edades)

# %%
# Crear un Dataframe con las edades
df = pd.DataFrame({'Edad': edades})
df

# %%
# Calcular el numero de intervalos utilizando la regla de Sturges
n = len(edades)
K = int(1 + math.log2(n))
print("Valor de n = ", n , "\nNumero de Intervalos =", K)

# %%
# Crear la tabla de Frecuencias

tabla_frecuencias = pd.cut(df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns = ['Clase', 'Frec']
tabla_frecuencias

# %%
# Ordenar la tabla de Frecuencia por el intervalo
tabla_frecuencias = tabla_frecuencias.sort_values(by='CLase')
tabla_frecuencias

# %%
# Generar las columnas siguientes
tabla_frecuencias['Frec Rel'] = tabla_frecuencias['Frec'] / n
tabla_frecuencias['Frec Porc'] = tabla_frecuencias['Frec'] n * 100
tabla_frecuencias['Frec Ac'] = tabla_frecuencias['Frec'].cumsum()
tabla_frecuencias['Frec Rel Ac'] = tabla_frecuencias['Frecuencia Relativa'].cumsum()
tabla_frecuencias['Frecuencia Porcentual Acumulada'] = tabla_frecuencias['Frecuencia Porcentual'].cumsum()

# Mostrar la tabla de frecuencia
print(tabla_frecuencias)
# Out:
#   File "<ipython-input-24-9f17c75138d8>", line 3
#     tabla_frecuencias['Frecuencia Porcentual'] = tabla_frecuencias['Frecuencia'] n * 100
#                                                                                  ^
# SyntaxError: invalid syntax
