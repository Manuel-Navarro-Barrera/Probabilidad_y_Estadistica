# %% [markdown]
# <a href="https://colab.research.google.com/github/Manuel-Navarro-Barrera/Probabilidad_y_Estadistica/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 12
b = 25
if a > b:
    print("a es mayor que b")
else:
    print("b es mayor que a")
# Out:
# b es mayor que a

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
# #Probabilidad y Estadistica
#
# ## Unidad 1
#
# ### Grupo **2Z**
#
# ### Practica 0: Introduccion a Python
#
# Alumno: Manuel Alejandro Navarro Barrera
#
# Docente: Dr. Jose Gabriel Rodriguez Arrivas

# %%
#esto es un comentario
for i in range(10):
    print(i)
    print("hola", i)
print("Fuera del for")
# Out:
# 0
# hola 0
# 1
# hola 1
# 2
# hola 2
# 3
# hola 3
# 4
# hola 4
# 5
# hola 5
# 6
# hola 6
# 7
# hola 7
# 8
# hola 8
# 9
# hola 9
# Fuera del for
