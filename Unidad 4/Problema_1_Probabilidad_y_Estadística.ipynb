# %% [markdown]
# <a href="https://colab.research.google.com/github/Manuel-Navarro-Barrera/Probabilidad_y_Estadistica/blob/main/Unidad%204/Problema_1_Probabilidad_y_Estad%C3%ADstica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #*Problema 1*
# ######Una revisión de los pesos de 500 estudiantes del ITD, evidenció que la media es de 70 kilogramos y la desviación estándar es de 4 kilogramos. Suponiendo que los valores se distribuyen normalmente. Hallar lo siguiente:
#
#
# ---
#
#
#
# ###### -La probabilidad de estudiantes que pesan más de 68 y menos de 72 kg.
# ###### -Cuantos estudiantes pesan más de 68 y menos de 72 kg.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
media = 70
desv_std = 4
num_datos = 500


datos = np .random.normal (media , desv_std , num_datos)
datos[0:500]
# Out:
# array([69.58619188, 67.12159637, 71.8353733 , 71.51998093, 69.40232429,
#        64.98383471, 67.99212152, 69.6665624 , 70.04645158, 68.8997076 ,
#        63.81097747, 66.07025538, 71.92228328, 69.85897065, 73.82081693,
#        65.49005223, 69.73426101, 65.55993205, 73.78144671, 76.16874636,
#        65.29012343, 72.53587511, 77.31053232, 66.96231799, 70.83457909,
#        68.00117263, 70.22178184, 66.31631848, 67.55697602, 69.09535994,
#        68.39958375, 68.92150856, 67.50444578, 70.30395892, 67.89344889,
#        68.69900596, 69.12146912, 74.3323366 , 70.51894625, 66.26405048,
#        72.026448  , 75.34889139, 70.97713034, 71.07076042, 70.28935745,
#        73.47616223, 69.64028688, 69.14296934, 69.13163115, 70.20866156,
#        75.56891858, 72.06374871, 71.9966792 , 67.52601545, 74.71322072,
#        65.68783885, 65.22751871, 68.51032984, 63.07481963, 58.90909852,
#        68.74368594, 63.45609152, 69.7345552 , 70.66373267, 70.65042645,
#        67.94850357, 70.75295801, 71.49411215, 74.66845314, 69.37245667,
#        75.09394527, 71.49110687, 69.11877139, 72.80516989, 71.61705858,
#        76.14979533, 68.84763676, 61.96873567, 67.29524182, 63.75592019,
#        68.98466111, 70.41026241, 74.78585549, 77.00279927, 70.49121918,
#        69.75195354, 70.22524182, 70.83490655, 71.8657702 , 68.41551823,
#        67.33223922, 73.10638701, 70.68862357, 76.33911626, 70.96557814,
#        59.27602512, 75.03344078, 66.23719298, 74.16467004, 65.12375861,
#        74.33344976, 73.9371071 , 70.22062327, 68.51046382, 69.01153626,
#        66.250142  , 74.05198489, 71.42987614, 67.58962886, 65.73451674,
#        67.21728872, 70.57742257, 72.14820349, 71.57234938, 71.77114255,
#        72.64342718, 73.37742282, 66.92264018, 70.48875794, 72.55145149,
#        72.22661654, 71.08519003, 58.42344734, 66.61976767, 71.06628191,
#        67.89270543, 68.32437872, 68.39723284, 66.60847224, 76.19335741,
#        71.15325379, 62.10801596, 71.77829963, 70.333124  , 66.24122502,
#        69.06736239, 69.59738818, 65.55037563, 65.33966317, 68.50876134,
#        81.99241893, 68.65986458, 71.22083336, 72.11123016, 66.93821106,
#        75.28861852, 69.45935247, 63.83798439, 68.60982479, 73.85656955,
#        66.65850892, 74.78296514, 73.2316915 , 62.73207466, 71.93215018,
#        71.36292323, 62.78469573, 76.1078727 , 70.10875161, 65.26966907,
#        75.72213522, 72.76365561, 67.83263868, 68.65800902, 82.99308363,
#        68.62679286, 67.98902817, 74.87098052, 71.22304766, 65.04295602,
#        69.48616257, 69.84994029, 65.26316296, 71.77475933, 66.68381011,
#        63.57757716, 68.90160111, 73.64027559, 72.26828719, 69.34286466,
#        77.4318677 , 67.90198314, 65.45286315, 73.1319228 , 74.81081596,
#        73.40136961, 66.28650619, 79.11582789, 67.52299602, 70.59333921,
#        68.58850308, 72.51438655, 73.33504509, 66.0507314 , 73.80413787,
#        67.18831075, 68.0654043 , 66.33131784, 65.93502404, 64.36589526,
#        65.9816561 , 65.15882358, 66.92376526, 60.59510162, 72.12896094,
#        73.61785956, 66.73740301, 63.97831363, 73.01464887, 69.25775161,
#        75.76721812, 68.78816935, 72.44861758, 65.26599455, 71.87411291,
#        71.2744472 , 66.81747203, 71.19604825, 71.27374355, 68.8544181 ,
#        73.34355696, 72.67166738, 61.87394932, 68.11202379, 68.34400651,
#        72.4777068 , 72.34704139, 67.26582065, 66.66317961, 82.08815913,
#        67.34525227, 69.95616672, 69.6489246 , 68.55533269, 77.05534142,
#        66.11049284, 68.33789157, 76.50052263, 71.95799085, 69.76880804,
#        79.2321989 , 67.23899602, 62.07408102, 71.57675084, 64.32578682,
#        70.49187368, 66.16955082, 66.73793466, 71.04134446, 67.43503475,
#        74.03425534, 69.03158275, 63.031361  , 67.42881867, 74.80839388,
#        64.97977062, 70.36991518, 70.53339618, 73.59465489, 68.4496244 ,
#        72.92295971, 74.04773268, 69.67950528, 68.18866852, 67.32188643,
#        68.66320521, 64.18578685, 73.16766307, 67.80223087, 70.37968362,
#        64.77271644, 74.42095208, 69.310267  , 63.1355792 , 75.54471631,
#        76.10751974, 69.82636178, 67.99274423, 66.97806004, 70.57106208,
#        61.40523239, 74.25481612, 68.34746745, 72.98639505, 74.82049261,
#        61.84344372, 73.65223212, 73.49317104, 64.57635418, 73.01948432,
#        67.08223837, 71.90056091, 67.86684359, 70.58745958, 74.65123846])

# %%
# # Crear un rango de valores para crear una densidad
x = np.linspace(media - 3 * desv_std, media + 3 * desv_std, num_datos)

# # # Calcular la PDF de la distribucion normal
pdf = 1 / (desv_std * np.sqrt(2 * np.pi)) * np.exp(-(x - media) ** 2 / (2 * desv_std ** 2))

# %%
# Graficar Histograma
plt.figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, color='b') # Histograma de los datos
plt.title('Distribucion Normal')
plt.xlabel('Peso en kg de los Estudiantes')
plt.grid(True)
plt.show()

# %%
# Vizualizar la PDF
plt.figure(figsize=(6, 4))
plt.plot(x, pdf, label='Normal:(media:{}; ds:{})'.format(np.round(media, 2), np.round(desv_std, 2)))
plt.title('Funcion de Densidad de Probabilidad (PDF) - Distribucion Normal')
plt.xlabel('Peso en kg. de los Estudiantes')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Graficar Histograma
plt.figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, density=True, color='b')
plt.plot(x, pdf, 'k', linewidth=2, )

plt.title('Distribucion Normal')
plt.xlabel('Peso en kg de los Estudiantes')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 4))

# Parametros de la distribucion normal
media = 70 # Media
desv_std = 4 # Desviacion Estandar
total_estudiantes = 500

# VARIABLE para calculo de la probabilidad de que un estudiante pese menos de 75 kg
peso_limite = 72

prob_menos_72kg = norm.cdf(peso_limite, media, desv_std)

# %%
estudiantes_menos_72kg = total_estudiantes * prob_menos_72kg

print("Probabilidad de que un estudiante pese menos de 72 kg:",prob_menos_72kg)
print("Numero de estudiantes que pesan menos de 72 kg:", estudiantes_menos_72kg)

x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, 1000)
y = norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x <= peso_limite), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese menos de 72 kg. \n $\mu=70$, $\sigma=4$, x=500')
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de Probabilidad')
plt.grid(True)
plt.show()
# Out:
# Probabilidad de que un estudiante pese menos de 72 kg: 0.6914624612740131
# Numero de estudiantes que pesan menos de 72 kg: 345.73123063700655

# %%
plt.figure(figsize=(6, 4))

media = 70
desv_std = 4
peso_limite = 68
total_estudiantes = 500

prob_menos_68kg = norm.cdf(peso_limite, media, desv_std)

prob_mas_68kg = 1 - prob_menos_72kg

estudiantes_mas_68kg = total_estudiantes * prob_mas_68kg

print("Probabilidad de que un estudiante pese mas de 68 kg:", prob_mas_68kg)
print("Numero aproximado de estudiantes que pesan mas 68 79 kg:", estudiantes_mas_68kg)
# Out:
# Probabilidad de que un estudiante pese mas de 68 kg: 0.3085375387259869
# Numero aproximado de estudiantes que pesan mas 68 79 kg: 154.26876936299345

# %%
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x >= peso_limite), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese mas de 68 kg. \n $\mu=70$, $\sigma=4$, x=500')
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de Probabilidad')
plt.grid(True)
plt.show()

# %% [markdown]
# # Combinando las dos graficas nos da:

# %%
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x >= 68), color='skyblue', alpha=0.5, label='Peso > 68 kg')
plt.fill_between(x, y, where=(x <= 72), color='skyblue', alpha=0.5, label='Peso < 72 kg')

prob_mas_68kg = 1 - norm.cdf(68, media, desv_std)
prob_menos_72kg = norm.cdf(72, media, desv_std)

estudiantes_mas_68kg = int(total_estudiantes * prob_mas_68kg)
estudiantes_menos_72kg = int(total_estudiantes * prob_menos_72kg)

plt.title('Distribucion de pesos de estudiantes\n $\mu=70$, $\sigma=4$, x=500')
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()
